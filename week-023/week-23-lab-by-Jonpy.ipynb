# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 23 Lab</h1>
# </div>

# %% [markdown]
# ### By Juan Peralta

# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # Exercise 1
#
# Plot one chart using matplotlib (OOP-style) using the following data.

# %%
df = pd.read_csv('../datasets/GOOG.csv')
df
# Out:
#             Date        Open        High         Low       Close   Volume  \
# 0     2015-12-31  769.500000  769.500000  758.340027  758.880005  1489600
# 1     2015-12-30  776.599976  777.599976  766.900024  771.000000  1293300
# 2     2015-12-29  766.690002  779.979980  766.429993  776.599976  1765000
# 3     2015-12-28  752.919983  762.989990  749.520020  762.510010  1515300
# 4     2015-12-24  749.549988  751.349976  746.619995  748.400024   527200
# ...          ...         ...         ...         ...         ...      ...
# 1253  2011-01-07  615.911064  618.251043  610.131047  616.441059  4218100
# 1254  2011-01-06  610.681075  618.431037  610.051036  613.501059  4131000
# 1255  2011-01-05  600.071002  610.331074  600.051030  609.071056  5083500
# 1256  2011-01-04  605.621034  606.181048  600.121055  602.121019  3662600
# 1257  2011-01-03  596.481052  605.591014  596.481052  604.351030  4748100
#
#        Adj Close
# 0     758.880005
# 1     771.000000
# 2     776.599976
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
fig, ax = plt.subplots(figsize=(24,12))
ax.plot(df["Date"][:10], df[["High","Low"]][:10], label = "X labe;")
ax.set_xlabel('Dates')  # Add an x-label to the axes.
ax.set_ylabel('Average Prices')  # Add a y-label to the axes.
ax.set_title("Top 10 High and Low prices for Google Stock Market Prices in December 2015")  # Add a title to the axes.
ax.legend(["High", "Low"])
plt.show()

# %% [markdown]
# # Exercise 2
#
# Perform some initial exploratory analysis to the following dataframe. Then plot two or more charts related to the data.

# %%
df_testers = pd.read_csv('../datasets/SHSAT-Registrations-and-Testers.csv')
df_testers
# Out:
#         DBN                            School name  Year of SHST  Grade level  \
# 0    05M046                 P.S. 046 Arthur Tappan          2013            8
# 1    05M046                 P.S. 046 Arthur Tappan          2014            8
# 2    05M046                 P.S. 046 Arthur Tappan          2015            8
# 3    05M046                 P.S. 046 Arthur Tappan          2016            8
# 4    05M123               P.S. 123 Mahalia Jackson          2013            8
# ..      ...                                    ...           ...          ...
# 135  84M709  Harlem Village Academy Charter School          2016            9
# 136  84M726  KIPP STAR College Prep Charter School          2013            8
# 137  84M726  KIPP STAR College Prep Charter School          2014            8
# 138  84M726  KIPP STAR College Prep Charter School          2015            8
# 139  84M726  KIPP STAR College Prep Charter School          2016            8
#
# ...

# %%
df_testers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   DBN                                              140 non-null    object
#  1   School name                                      140 non-null    object
#  2   Year of SHST                                     140 non-null    int64
#  3   Grade level                                      140 non-null    int64
#  4   Enrollment on 10/31                              140 non-null    int64
#  5   Number of students who registered for the SHSAT  140 non-null    object
#  6   Number of students who took the SHSAT            140 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 7.8+ KB

# %%
df_testers = df_testers.rename(columns={'Number of students who registered for the SHSAT': 'SAT Registered', "Number of students who took the SHSAT": "SAT Tested"})

# %%
df_testers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DBN                  140 non-null    object
#  1   School name          140 non-null    object
#  2   Year of SHST         140 non-null    int64
#  3   Grade level          140 non-null    int64
#  4   Enrollment on 10/31  140 non-null    int64
#  5   SAT Registered       140 non-null    int64
#  6   SAT Tested           140 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 7.8+ KB

# %%
sns.pairplot(df_testers)
plt.show()

# %%
df_testers.corr()
# Out:
#                      Year of SHST  Grade level  Enrollment on 10/31  \
# Year of SHST             1.000000     0.054234            -0.029023
# Grade level              0.054234     1.000000             0.354346
# Enrollment on 10/31     -0.029023     0.354346             1.000000
# SAT Registered          -0.099892    -0.575594            -0.060419
# SAT Tested              -0.003468    -0.632743            -0.023242
#
#                      SAT Registered  SAT Tested
# Year of SHST              -0.099892   -0.003468
# Grade level               -0.575594   -0.632743
# Enrollment on 10/31       -0.060419   -0.023242
# SAT Registered             1.000000    0.748463
# SAT Tested                 0.748463    1.000000

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df_testers["SAT Registered"].astype(int), y=df_testers["SAT Tested"])

plt.ylabel('SAT Tested')
plt.xlabel('SAT Registered')
plt.show()

# %%
# Heatmap showing average arrival delay for each airline by month
plt.title("Correlation Analysis")
sns.heatmap(data=df_testers[["Grade level", "SAT Registered", 'SAT Tested']].corr(), annot=True)

plt.show()

# %%
#y_train.values.reshape(-1,1)
x = df_testers["SAT Registered"]
y = df_testers["SAT Tested"]
x = x.values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
# reg.fit(X_train.values.reshape(-1,1), y_train.values.reshape(-1,1))
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# score = reg.score(X_test.values.reshape(-1,1), y_test.values.reshape(-1,1))
score = reg.score(X_test, y_test.values)

# %%
fit_line = np.arange(45).reshape(-1,1)
sns.regplot(x="SAT Registered", y="SAT Tested", data=df_testers, fit_reg=True)
plt.plot(fit_line, reg.predict(fit_line))

plt.show()

# %%
#I think, we can tell that from the test data only 35-40% of registered students took the Test.

# %% [markdown]
# # Exercise 3
#
# [removed]

# %% [markdown]
# # Bonus:
# Perform some initial exploratory analysis to the following dataframe. Then plot one chart related to the data. Run a logistic regression on the data to see if you can classify companies (use `Bankrupt?` as your Y variable).

# %%
df = pd.read_csv('../datasets/data.csv')
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Work On Projects</h1>
# </div>
